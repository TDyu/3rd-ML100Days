# %% [markdown]
# # 作業 : (Kaggle)房價預測

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 在房價預測中, 觀察去除離群值的影響

# %% [markdown]
# # [作業重點]
# - 觀察將極端值以上下限值取代, 對於分布與迴歸分數的影響 (In[5], Out[5])
# - 觀察將極端值資料直接刪除, 對於分布與迴歸分數的影響 (In[6], Out[6])

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

data_path = 'data/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')

train_Y = np.log1p(df_train['SalePrice'])
df = df_train.drop(['Id', 'SalePrice'] , axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          60       RL         65.0  ...    2008       WD        Normal
# 1          20       RL         80.0  ...    2007       WD        Normal
# 2          60       RL         68.0  ...    2008       WD        Normal
# 3          70       RL         60.0  ...    2006       WD       Abnorml
# 4          60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]

# %%
#只取 int64, float64 兩種數值型欄位, 存於 num_features 中
num_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
print(f'{len(num_features)} Numeric Features : {num_features}\n')
# Out:
# 36 Numeric Features : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
# 削減文字型欄位, 只剩數值型欄位
df = df[num_features]
df = df.fillna(-1)
MMEncoder = MinMaxScaler()
train_num = train_Y.shape[0]
df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold
# 0          60         65.0     8450  ...        0       2    2008
# 1          20         80.0     9600  ...        0       5    2007
# 2          60         68.0    11250  ...        0       9    2008
# 3          70         60.0     9550  ...        0       2    2006
# 4          60         84.0    14260  ...        0      12    2008
#
# [5 rows x 36 columns]

# %% [markdown]
# # 作業1
# * 試著限制 '1樓地板面積(平方英尺)' (1stFlrSF) 欄位的上下限, 看看能否再進一步提高分數?

# %%
# 顯示 1stFlrSF 與目標值的散佈圖
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x = df['1stFlrSF'][:train_num], y=train_Y)
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8466046274204875

# %%
# 以 IQR 挑選上下限
q1, q3 = np.percentile(df['1stFlrSF'][:train_num], [25, 75])
IQR = q3 - q1
IQR_upper = q3 + 1.5 * IQR
IQR_lower = q1 - 1.5 * IQR

IQR_upper, IQR_lower
# Out:
# (2155.125, 118.125)

# %%
# 以 IQR 調整離群值
df_IQR = df
df_IQR['1stFlrSF'][:train_num] = df['1stFlrSF'][:train_num].clip(IQR_lower, IQR_upper)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sns.regplot(x = df_IQR['1stFlrSF'], y=train_Y)
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df_IQR)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8829483361962662

# %% [markdown]
# # 作業2
# * 續前題, 去除離群值有兩類方式 :  捨棄離群值(刪除離群的資料) 以及調整離群值,
# 請試著用同樣的上下限, 改為 '捨棄離群值' 的方法, 看看結果會變好還是變差? 並試著解釋原因。

# %%
# 以 IQR 捨棄離群值
keep_row_indexs_boolean_list = (df['1stFlrSF'][:train_num] < IQR_upper) & (df['1stFlrSF'][:train_num] > IQR_lower)
df_drop_IQR = df[keep_row_indexs_boolean_list]
train_Y_drop_IQR = train_Y[keep_row_indexs_boolean_list]

# %%
sns.regplot(x = df_drop_IQR['1stFlrSF'], y=train_Y_drop_IQR)
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df_drop_IQR)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y_drop_IQR, cv=5).mean()
# Out:
# 0.8893225328119373

# %% [markdown]
# 此例以 IQR 取上下限
#
# 結果效果為: 捨棄離群值(0.889) > 調整離群值(0.883)
#
# 可能因為調整的離群值不同區間的數據量會有偏頗
